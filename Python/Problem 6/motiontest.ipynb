# %%
import motion as m
m.projectile()
# Out:
# (19.883236311377413, 1.5306122448979589, 2.8698979591836724)

# %%
m.projectile(10,20,10)
# Out:
# (17.098498358849913, 1.819584189620394, 10.596825400206688)

# %%
m.freefall()
# Out:
# (-44.294469180700204, 4.515236409857309)

# %%
m.freefall(1000)
# Out:
# (-140.07141035914503, 14.278431229270645)
